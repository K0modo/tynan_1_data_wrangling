# %% [markdown]
# ## W.5 Wrangle Provider_POS (Place of Service)

# %% [markdown]
# Observation: The Center for Medicare and Medicaid Services (CMS) uses a 2 digit code to identify the "type" of facilities that provide health services.  The codes ranage between 0-99.  The current data only tracks the code and not the "type"
#
#
# Goal: Develop Dictionary to map the POS_Code to the "type" Description and add new column for "POS_Desc"

# %% [markdown]
# ### Table of Contents

# %% [markdown]
# 1. <a href="#1.-Libraries-&-Environment">Libraries & Environment</a>
# 2. <a href="#2.-Settings">Settings</a>
# 3. <a href="#3.-Data-Source">Data Source</a>
# 4. <a href="#4.-Import-POS-Description-Table">Import POS Description Table</a>
# 5. <a href="#5.-Create-Dictionary-to-map-_POS_Code-to-_POS_Desc">Create Dictionary to map _POS_Code to POS_Desc</a>
# 6. <a href="#6.-Map-_POS_Desc-in-New-Column">Map _POS_Desc in New Column</a>
# 7. <a href="#7.-Quality-Control">Quality Control</a>

# %% [markdown]
# ### 1. Libraries & Environment

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# [<a href='#Table-of-Contents'>Table of Contents</a>]

# %% [markdown]
# ### 2. Settings

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.options.display.width

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

pd.options.display.float_format = '{:,.0f}'.format

import winsound
duration = 1300
freq = 440

# %% [markdown]
# [<a href='#Table-of-Contents'>Table of Contents</a>]

# %% [markdown]
# ### 3. Data Source

# %%
df = pd.read_pickle('DataFiles/AnnualpickleAug9.pkl')
df.head()
winsound.Beep(freq,duration)
# Out:
#    Mem_Acct Prov_ID Prov_Specialty_Code Prov_Specialty_Desc Prov_Spec_Code_Num Claim_ID Claim_Line_Item Claim_File_Date Claim_POS                 Claim_POS_Desc Claim_ICD1 Claim_ICD1.1 Claim_ICD_Desc  Charge  Charge_Allowed  Charge_CoPay  Charge_Deduct  Charge_CoIn  Charge_CMS  Charge_Other1  Charge_Other2  Charge_Other3  Charge_Paid Charge_Trans Charge_Trans_Date Charge_Type  Pay_Period Fiscal_Year Pay_Quarter  Out_Pocket
# 0    455716   86941                PATH           PATHOLOGY                 19  7842027               1      2019-06-05        23      Emergency Room – Hospital    L02.411         12.0    Skin_Tissue      20              16             0              0            0           0              0              0              0           16       505921        2019-11-16     Payment           2        2020          Q1           0
# 1    455716   86941                PATH           PATHOLOGY                 19  7842027               2      2019-06-05        23      Emergency Room – Hospital    L02.411         12.0    Skin_Tissue      20              16             0              0            0           0              0              0              0           16       505921        2019-11-16     Payment           2        2020          Q1           0
# 2    455716  406859                GENE     GENERAL SURGERY                  8  7895211               1      2019-06-07        22  On Campus-Outpatient Hospital    L03.111         12.0    Skin_Tissue    1161             917             0              0            0           0              0              0              0          917       505934        2019-11-18     Payment           2        2020          Q1           0
# 3    455716  406859                GENE     GENERAL SURGERY                  8  7895214               1      2019-06-08        22  On Campus-Outpatient Hospital    L03.111         12.0    Skin_Tissue     657             519             0              0            0           0              0              0              0          519       505934        2019-11-18     Payment           2        2020          Q1           0
# 4    455716  406859                GENE     GENERAL SURGERY                  8  7927104               1      2019-06-09        22  On Campus-Outpatient Hospital    L03.111         12.0    Skin_Tissue     453             358             0              0            0           0              0              0              0          358       505934        2019-11-18     Payment           2        2020          Q1           0

# %% [markdown]
# [<a href='#Table-of-Contents'>Table of Contents</a>]

# %% [markdown]
# ### 4. Import POS Description Table

# %% [markdown]
# [<a href="https://www.cms.gov/Medicare/Coding/place-of-service-codes/Place_of_Service_Code_Set">CMS Table for Place of Service Website</a>]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148333 entries, 0 to 148332
# Data columns (total 30 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Mem_Acct             148333 non-null  int32
#  1   Prov_ID              148333 non-null  object
#  2   Prov_Specialty_Code  148333 non-null  object
#  3   Prov_Specialty_Desc  148333 non-null  object
#  4   Prov_Spec_Code_Num   148333 non-null  object
#  5   Claim_ID             148333 non-null  object
#  6   Claim_Line_Item      148333 non-null  object
#  7   Claim_File_Date      148333 non-null  datetime64[ns]
#  8   Claim_POS            148333 non-null  object
#  9   Claim_POS_Desc       148333 non-null  object
#  10  Claim_ICD1           148305 non-null  object
#  11  Claim_ICD1.1         148333 non-null  object
#  12  Claim_ICD_Desc       148301 non-null  object
#  13  Charge               148333 non-null  int64
#  14  Charge_Allowed       148333 non-null  int64
#  15  Charge_CoPay         148333 non-null  int64
#  16  Charge_Deduct        148333 non-null  int64
#  17  Charge_CoIn          148333 non-null  int64
#  18  Charge_CMS           148333 non-null  int64
#  19  Charge_Other1        148333 non-null  int64
#  20  Charge_Other2        148333 non-null  int64
#  21  Charge_Other3        148333 non-null  int64
#  22  Charge_Paid          148333 non-null  int64
#  23  Charge_Trans         148333 non-null  object
#  24  Charge_Trans_Date    148333 non-null  datetime64[ns]
#  25  Charge_Type          148333 non-null  object
#  26  Pay_Period           148333 non-null  int32
#  27  Fiscal_Year          148333 non-null  object
#  28  Pay_Quarter          148333 non-null  object
#  29  Out_Pocket           148333 non-null  int64
# dtypes: datetime64[ns](2), int32(2), int64(11), object(15)
# memory usage: 32.8+ MB

# %%
# PURPOSE: Import POS Description from CMS Table at their website.  (See link above). Cast POS_Code as str


xls = pd.ExcelFile('DataFiles\POS_Table1.xlsx')
Excel_POS_Desc_Table = pd.read_excel(xls, 'Sheet1')
Excel_POS_Desc_Table.POS_Code = Excel_POS_Desc_Table.POS_Code.astype(str)
Excel_POS_Desc_Table
# Out:
#    POS_Code                                    POS_Description
# 0         1                                           Pharmacy
# 1         2   Telehealth Provided Other than in Patient’s Home
# 2         3                                             School
# 3         4                                   Homeless Shelter
# 4         5                              Indian Health Service
# 5         6                              Indian Health Service
# 6         7                                         Tribal 638
# 7         8                                         Tribal 638
# 8         9                                            Prison/
# 9        10              Telehealth Provided in Patient’s Home
# 10       11                                             Office
# 11       12                                               Home
# 12       13                           Assisted Living Facility
# 13       14                                       Group Home *
# 14       15                                        Mobile Unit
# 15       16                                  Temporary Lodging
# 16       17                       Walk-in Retail Health Clinic
# 17       18                               Place of Employment-
# 18       19                     Off Campus-Outpatient Hospital
# 19       20                               Urgent Care Facility
# 20       21                                 Inpatient Hospital
# 21       22                      On Campus-Outpatient Hospital
# 22       23                          Emergency Room – Hospital
# 23       24                         Ambulatory Surgical Center
# 24       25                                    Birthing Center
# 25       26                        Military Treatment Facility
# 26       27                             Other Place of Service
# 27       28                             Other Place of Service
# 28       29                             Other Place of Service
# 29       30                             Other Place of Service
# 30       31                           Skilled Nursing Facility
# 31       32                                   Nursing Facility
# 32       33                            Custodial Care Facility
# 33       34                                            Hospice
# 34       35                             Other Place of Service
# 35       36                             Other Place of Service
# 36       37                             Other Place of Service
# 37       38                             Other Place of Service
# 38       39                             Other Place of Service
# 39       40                             Other Place of Service
# 40       41                                   Ambulance - Land
# 41       42                           Ambulance – Air or Water
# 42       43                             Other Place of Service
# 43       44                             Other Place of Service
# 44       45                             Other Place of Service
# 45       46                             Other Place of Service
# 46       47                             Other Place of Service
# 47       48                             Other Place of Service
# 48       49                                 Independent Clinic
# 49       50                  Federally Qualified Health Center
# 50       51                     Inpatient Psychiatric Facility
# 51       52       Psychiatric Facility-Partial Hospitalization
# 52       53                     Community Mental Health Center
# 53       54  Intermediate Care Facility/ Individuals with I...
# 54       55     Residential Substance Abuse Treatment Facility
# 55       56           Psychiatric Residential Treatment Center
# 56       57  Non-residential Substance Abuse Treatment Faci...
# 57       58          Non-residential Opioid Treatment Facility
# 58       59                             Other Place of Service
# 59       60                           Mass Immunization Center
# 60       61    Comprehensive Inpatient Rehabilitation Facility
# 61       62   Comprehensive Outpatient Rehabilitation Facility
# 62       63                             Other Place of Service
# 63       64                             Other Place of Service
# 64       65         End-Stage Renal Disease Treatment Facility
# 65       66                             Other Place of Service
# 66       67                             Other Place of Service
# 67       68                             Other Place of Service
# 68       69                             Other Place of Service
# 69       70                             Other Place of Service
# 70       71                               Public Health Clinic
# 71       72                                Rural Health Clinic
# 72       73                             Other Place of Service
# 73       74                             Other Place of Service
# 74       75                             Other Place of Service
# 75       76                             Other Place of Service
# 76       77                             Other Place of Service
# 77       78                             Other Place of Service
# 78       79                             Other Place of Service
# 79       80                             Other Place of Service
# 80       81                             Independent Laboratory
# 81       99                             Other Place of Service

# %% [markdown]
# [<a href='#Table-of-Contents'>Table of Contents</a>]

# %% [markdown]
# ### 5. Create Dictionary to map _POS_Code to _POS_Desc

# %%
# PURPOSE: 

dict_POS_Desc = Excel_POS_Desc_Table.set_index('POS_Code').to_dict()['POS_Description']
dict_POS_Desc
# Out:
# {'1': 'Pharmacy',
#  '2': 'Telehealth Provided Other than in Patient’s Home',
#  '3': 'School',
#  '4': 'Homeless Shelter',
#  '5': 'Indian Health Service',
#  '6': 'Indian Health Service',
#  '7': 'Tribal 638',
#  '8': 'Tribal 638',
#  '9': 'Prison/',
#  '10': 'Telehealth Provided in Patient’s Home',
#  '11': 'Office',
#  '12': 'Home',
#  '13': 'Assisted Living Facility',
#  '14': 'Group Home *',
#  '15': 'Mobile Unit',
#  '16': 'Temporary Lodging',
#  '17': 'Walk-in Retail Health Clinic',
#  '18': 'Place of Employment-',
#  '19': 'Off Campus-Outpatient Hospital',
#  '20': 'Urgent Care Facility',
#  '21': 'Inpatient Hospital',
#  '22': 'On Campus-Outpatient Hospital',
#  '23': 'Emergency Room – Hospital',
#  '24': 'Ambulatory Surgical Center',
#  '25': 'Birthing Center',
#  '26': 'Military Treatment Facility',
#  '27': 'Other Place of Service',
#  '28': 'Other Place of Service',
#  '29': 'Other Place of Service',
#  '30': 'Other Place of Service',
#  '31': 'Skilled Nursing Facility',
#  '32': 'Nursing Facility',
#  '33': 'Custodial Care Facility',
#  '34': 'Hospice',
#  '35': 'Other Place of Service',
#  '36': 'Other Place of Service',
#  '37': 'Other Place of Service',
#  '38': 'Other Place of Service',
#  '39': 'Other Place of Service',
#  '40': 'Other Place of Service',
#  '41': 'Ambulance - Land',
#  '42': 'Ambulance – Air or Water',
#  '43': 'Other Place of Service',
#  '44': 'Other Place of Service',
#  '45': 'Other Place of Service',
#  '46': 'Other Place of Service',
#  '47': 'Other Place of Service',
#  '48': 'Other Place of Service',
#  '49': 'Independent Clinic',
#  '50': 'Federally Qualified Health Center',
#  '51': 'Inpatient Psychiatric Facility',
#  '52': 'Psychiatric Facility-Partial Hospitalization',
#  '53': 'Community Mental Health Center',
#  '54': 'Intermediate Care Facility/ Individuals with Intellectual Disabilities',
#  '55': 'Residential Substance Abuse Treatment Facility',
#  '56': 'Psychiatric Residential Treatment Center',
#  '57': 'Non-residential Substance Abuse Treatment Facility',
#  '58': 'Non-residential Opioid Treatment Facility',
#  '59': 'Other Place of Service',
#  '60': 'Mass Immunization Center',
#  '61': 'Comprehensive Inpatient Rehabilitation Facility',
#  '62': 'Comprehensive Outpatient Rehabilitation Facility',
#  '63': 'Other Place of Service',
#  '64': 'Other Place of Service',
#  '65': 'End-Stage Renal Disease Treatment Facility',
#  '66': 'Other Place of Service',
#  '67': 'Other Place of Service',
#  '68': 'Other Place of Service',
#  '69': 'Other Place of Service',
#  '70': 'Other Place of Service',
#  '71': 'Public Health Clinic',
#  '72': 'Rural Health Clinic',
#  '73': 'Other Place of Service',
#  '74': 'Other Place of Service',
#  '75': 'Other Place of Service',
#  '76': 'Other Place of Service',
#  '77': 'Other Place of Service',
#  '78': 'Other Place of Service',
#  '79': 'Other Place of Service',
#  '80': 'Other Place of Service',
#  '81': 'Independent Laboratory',
#  '99': 'Other Place of Service'}

# %%
dict_POS_Desc1 = Excel_POS_Desc_Table.set_index('POS_Code').to_dict()

dict_POS_Desc1
# Out:
# {'POS_Description': {'1': 'Pharmacy',
#   '2': 'Telehealth Provided Other than in Patient’s Home',
#   '3': 'School',
#   '4': 'Homeless Shelter',
#   '5': 'Indian Health Service',
#   '6': 'Indian Health Service',
#   '7': 'Tribal 638',
#   '8': 'Tribal 638',
#   '9': 'Prison/',
#   '10': 'Telehealth Provided in Patient’s Home',
#   '11': 'Office',
#   '12': 'Home',
#   '13': 'Assisted Living Facility',
#   '14': 'Group Home *',
#   '15': 'Mobile Unit',
#   '16': 'Temporary Lodging',
#   '17': 'Walk-in Retail Health Clinic',
#   '18': 'Place of Employment-',
#   '19': 'Off Campus-Outpatient Hospital',
#   '20': 'Urgent Care Facility',
#   '21': 'Inpatient Hospital',
#   '22': 'On Campus-Outpatient Hospital',
#   '23': 'Emergency Room – Hospital',
#   '24': 'Ambulatory Surgical Center',
#   '25': 'Birthing Center',
#   '26': 'Military Treatment Facility',
#   '27': 'Other Place of Service',
#   '28': 'Other Place of Service',
#   '29': 'Other Place of Service',
#   '30': 'Other Place of Service',
#   '31': 'Skilled Nursing Facility',
#   '32': 'Nursing Facility',
#   '33': 'Custodial Care Facility',
#   '34': 'Hospice',
#   '35': 'Other Place of Service',
#   '36': 'Other Place of Service',
#   '37': 'Other Place of Service',
#   '38': 'Other Place of Service',
#   '39': 'Other Place of Service',
#   '40': 'Other Place of Service',
#   '41': 'Ambulance - Land',
#   '42': 'Ambulance – Air or Water',
#   '43': 'Other Place of Service',
#   '44': 'Other Place of Service',
#   '45': 'Other Place of Service',
#   '46': 'Other Place of Service',
#   '47': 'Other Place of Service',
#   '48': 'Other Place of Service',
#   '49': 'Independent Clinic',
#   '50': 'Federally Qualified Health Center',
#   '51': 'Inpatient Psychiatric Facility',
#   '52': 'Psychiatric Facility-Partial Hospitalization',
#   '53': 'Community Mental Health Center',
#   '54': 'Intermediate Care Facility/ Individuals with Intellectual Disabilities',
#   '55': 'Residential Substance Abuse Treatment Facility',
#   '56': 'Psychiatric Residential Treatment Center',
#   '57': 'Non-residential Substance Abuse Treatment Facility',
#   '58': 'Non-residential Opioid Treatment Facility',
#   '59': 'Other Place of Service',
#   '60': 'Mass Immunization Center',
#   '61': 'Comprehensive Inpatient Rehabilitation Facility',
#   '62': 'Comprehensive Outpatient Rehabilitation Facility',
#   '63': 'Other Place of Service',
#   '64': 'Other Place of Service',
#   '65': 'End-Stage Renal Disease Treatment Facility',
#   '66': 'Other Place of Service',
#   '67': 'Other Place of Service',
#   '68': 'Other Place of Service',
#   '69': 'Other Place of Service',
#   '70': 'Other Place of Service',
#   '71': 'Public Health Clinic',
#   '72': 'Rural Health Clinic',
#   '73': 'Other Place of Service',
#   '74': 'Other Place of Service',
#   '75': 'Other Place of Service',
#   '76': 'Other Place of Service',
#   '77': 'Other Place of Service',
#   '78': 'Other Place of Service',
#   '79': 'Other Place of Service',
#   '80': 'Other Place of Service',
#   '81': 'Independent Laboratory',
#   '99': 'Other Place of Service'}}

# %% [markdown]
# [<a href='#Table-of-Contents'>Table of Contents</a>]

# %% [markdown]
# ### 6. Map _POS_Desc in New Column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148333 entries, 0 to 148332
# Data columns (total 30 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Mem_Acct             148333 non-null  int32
#  1   Prov_ID              148333 non-null  object
#  2   Prov_Specialty_Code  148333 non-null  object
#  3   Prov_Specialty_Desc  148333 non-null  object
#  4   Prov_Spec_Code_Num   148333 non-null  object
#  5   Claim_ID             148333 non-null  object
#  6   Claim_Line_Item      148333 non-null  object
#  7   Claim_File_Date      148333 non-null  datetime64[ns]
#  8   Claim_POS            148333 non-null  object
#  9   Claim_POS_Desc       148333 non-null  object
#  10  Claim_ICD1           148305 non-null  object
#  11  Claim_ICD1.1         148333 non-null  object
#  12  Claim_ICD_Desc       148301 non-null  object
#  13  Charge               148333 non-null  int64
#  14  Charge_Allowed       148333 non-null  int64
#  15  Charge_CoPay         148333 non-null  int64
#  16  Charge_Deduct        148333 non-null  int64
#  17  Charge_CoIn          148333 non-null  int64
#  18  Charge_CMS           148333 non-null  int64
#  19  Charge_Other1        148333 non-null  int64
#  20  Charge_Other2        148333 non-null  int64
#  21  Charge_Other3        148333 non-null  int64
#  22  Charge_Paid          148333 non-null  int64
#  23  Charge_Trans         148333 non-null  object
#  24  Charge_Trans_Date    148333 non-null  datetime64[ns]
#  25  Charge_Type          148333 non-null  object
#  26  Pay_Period           148333 non-null  int32
#  27  Fiscal_Year          148333 non-null  object
#  28  Pay_Quarter          148333 non-null  object
#  29  Out_Pocket           148333 non-null  int64
# dtypes: datetime64[ns](2), int32(2), int64(11), object(15)
# memory usage: 32.8+ MB

# %%
# PURPOSE:  Create new column for POS_Desc and map to 

df['Claim_POS_Desc'] = df['Claim_POS'].map(dict_POS_Desc)

winsound.Beep(freq,duration)  # This is chime to notify "mapping" process is complete.

# %% [markdown]
# [<a href='#Table-of-Contents'>Table of Contents</a>]

# %% [markdown]
# [<a href='#Table-of-Contents'>Table of Contents</a>]

# %% [markdown]
# ### 7. Quality Control

# %%
# PURPOSE: Print output of Prov_ID statistics

qc_POS_Desc = df.filter(['Prov_ID'])
qc_Prov_ID.min()

qc_Prov_ID.max()

qc_Prov_ID
# Out:
# Prov_ID    011117
# dtype: object
# Prov_ID    999590
# dtype: object
#             Prov_ID
# Index_Claim
# 1            625296
# 2            625296
# 3            625296
# 4            625296
# 5            625296
# ...             ...
# 295433       625296
# 295434       625296
# 295435       625296
# 295436       625296
# 295437       861170
#
# [295437 rows x 1 columns]

# %% [markdown]
# [<a href='#Table-of-Contents'>Table of Contents</a>]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 295437 entries, 1 to 295437
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Mem_Acct               295437 non-null  object
#  1   Mem_SubAcct            295437 non-null  object
#  2   Mem_ID                 295437 non-null  object
#  3   Prov_ID                295437 non-null  object
#  4   Prov_Specialty_Code    295437 non-null  object
#  5   Prov_Specialty_Desc    295437 non-null  object
#  6   Claim_ID               295437 non-null  object
#  7   Claim_Line_Item        295437 non-null  object
#  8   Claim_File_Date        295437 non-null  datetime64[ns]
#  9   Claim_POS              295437 non-null  object
#  10  Claim_Bill_Code        295437 non-null  object
#  11  Claim_Bill_Desc        295246 non-null  object
#  12  Claim_Bill_Proce       295437 non-null  object
#  13  Claim_Bill_Proce_Desc  293991 non-null  object
#  14  Claim_ICD1             295176 non-null  object
#  15  Claim_ICD2             280316 non-null  object
#  16  Claim_ICD3             280315 non-null  object
#  17  Claim_Benefit          295437 non-null  object
#  18  Charge                 295437 non-null  int32
#  19  Charge_Allowed         295437 non-null  int32
#  20  Charge_CoPay           295437 non-null  int32
#  21  Charge_Dedect          295437 non-null  int32
#  22  Charge_CoIn            295437 non-null  int32
#  23  Charge_CMS             295437 non-null  int32
#  24  Charge_Other1          295437 non-null  int32
#  25  Charge_Other2          295437 non-null  int32
#  26  Charge_Other3          295437 non-null  int32
#  27  Charge_Paid            295437 non-null  int32
#  28  Charge_Trans           295437 non-null  object
#  29  Charge_Trans_Date      295437 non-null  datetime64[ns]
#  30  Prov_Desc_Split_Col    295437 non-null  object
#  31  Prov_Spec_Code_Num     295437 non-null  int64
# dtypes: datetime64[ns](2), int32(10), int64(1), object(19)
# memory usage: 63.1+ MB

# %%
df.head()
# Out:
#             Mem_Acct Mem_SubAcct     Mem_ID Prov_ID Prov_Specialty_Code Prov_Specialty_Desc  Claim_ID Claim_Line_Item Claim_File_Date Claim_POS Claim_Bill_Code                 Claim_Bill_Desc Claim_Bill_Proce        Claim_Bill_Proce_Desc Claim_ICD1 Claim_ICD2 Claim_ICD3 Claim_Benefit  Charge  Charge_Allowed  Charge_CoPay  Charge_Dedect  Charge_CoIn  Charge_CMS  Charge_Other1  Charge_Other2  Charge_Other3  Charge_Paid Charge_Trans Charge_Trans_Date Prov_Desc_Split_Col  Prov_Spec_Code_Num
# Index_Claim
# 1             217003           1  217003-01  625296                PHAR      PHARMACEUTICAL  P6868800               1      2018-10-24      99.0                            UB92 - REVENUE CODES            RXDED                RX DEDUCTIBLE      RXD.X        NaN        NaN        RXDEDU    2827            2827             0           2390            0           0              0              0            437            0       509796        2020-02-08            PHARMACY                  20
# 2             217003           1  217003-01  625296                PHAR      PHARMACEUTICAL  P6868800               2      2018-10-24      99.0                            UB92 - REVENUE CODES            RXCOI               RX COINSURANCE      RXD.X        NaN        NaN        RXCOIN      50              50             0              0           50           0              0              0              0            0       509796        2020-02-08            PHARMACY                  20
# 3             217003           1  217003-01  625296                PHAR      PHARMACEUTICAL  P6868800               3      2018-10-24      11.0             999  OTHER PATIENT CONVENIENCE ITEM            99199  SPECIAL SERVICE/PROC/REPORT      RXD.X        NaN        NaN                     0               0             0              0            0           0              0              0             12            0       509796        2020-02-08            PHARMACY                  20
# 4             457225           1  457225-01  625296                PHAR      PHARMACEUTICAL  P6907375               1      2018-02-14      99.0                            UB92 - REVENUE CODES            RXCOI               RX COINSURANCE      RXD.X        NaN        NaN        RXCOIN     575             575             0              0          575           0              0              0              0            0                     2020-01-28            PHARMACY                  20
# 5             306769           3  306769-03  625296                PHAR      PHARMACEUTICAL  P6907824               1      2018-04-20      99.0                            UB92 - REVENUE CODES            RXDED                RX DEDUCTIBLE      RXD.X        NaN        NaN        RXDEDU     585             585             0            585            0           0              0              0              0            0                     2020-02-08            PHARMACY                  20

# %%
df.to_pickle('DataFiles/AnnualpickleMar16')
winsound.Beep(freq,duration)
